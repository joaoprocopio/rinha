# %%
import json
import os
from pathlib import Path
import pandas as pd

exec_dir = Path(os.getcwd())
root_dir = exec_dir.parent

data_path = root_dir.joinpath("./ext/previa-resultados+participantes-info.json")

with open(data_path) as raw_data:
    data = json.load(raw_data)

# %%
df = pd.json_normalize(data)

df[['info.name', 'resultado_partial.p99.bonus']]
# Out:
#                      info.name resultado_partial.p99.bonus
# 0                      eber404                         10%
# 1                 Marcos Paulo                         NaN
# 2                  Arthur Isvi                         13%
# 3                Maxel Marques                          0%
# 4                          CGB                         14%
# ..                         ...                         ...
# 127     Murillo Sprengel Lange                         NaN
# 128                Lucas Souza                          0%
# 129   Felipe Libardi Gonçalves                          0%
# 130  Marcelo Eduardo Benencase                         NaN
# 131             Henrique Ramos                          0%
#
# [132 rows x 2 columns]
